# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import seaborn as sns
import string
from nltk.stem.porter import PorterStemmer
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('spam.csv',encoding='ISO-8859-1')

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 2024  ham            U having lunch alone? I now so bored...        NaN
# 793   ham  Omg I want to scream. I weighed myself and I l...        NaN
# 3291  ham             Dear good morning how you feeling dear        NaN
# 4942  ham  Check mail.i have mailed varma and kept copy t...        NaN
# 371   ham                 I will spoil you in bed as well :)        NaN
#
#      Unnamed: 3 Unnamed: 4
# 2024        NaN        NaN
# 793         NaN        NaN
# 3291        NaN        NaN
# 4942        NaN        NaN
# 371         NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %% [markdown]
# # Data cleaning

# %%
df_new=df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'])

# %%
df_new.head(5)
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
new_name = {'v1':'is_spam', 'v2':'sms'}
df_new.rename(columns=new_name, inplace=True)
df_new
# Out:
#      is_spam                                                sms
# 0        ham  Go until jurong point, crazy.. Available only ...
# 1        ham                      Ok lar... Joking wif u oni...
# 2       spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        ham  U dun say so early hor... U c already then say...
# 4        ham  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567    spam  This is the 2nd time we have tried 2 contact u...
# 5568     ham            Will ï¿½_ b going to esplanade fr home?
# 5569     ham  Pity, * was in mood for that. So...any other s...
# 5570     ham  The guy did some bitching but I acted like i'd...
# 5571     ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
encoder=LabelEncoder()

# %%
df_new['is_spam']=encoder.fit_transform(df_new['is_spam'])

# %%
df_new
# Out:
#       is_spam                                                sms
# 0           0  Go until jurong point, crazy.. Available only ...
# 1           0                      Ok lar... Joking wif u oni...
# 2           1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3           0  U dun say so early hor... U c already then say...
# 4           0  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567        1  This is the 2nd time we have tried 2 contact u...
# 5568        0            Will ï¿½_ b going to esplanade fr home?
# 5569        0  Pity, * was in mood for that. So...any other s...
# 5570        0  The guy did some bitching but I acted like i'd...
# 5571        0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
#checking for missing values

# %%
df_new.isnull().sum()
# Out:
# is_spam    0
# sms        0
# dtype: int64

# %%
df_new.duplicated().sum()
# Out:
# 403

# %%
df_new.drop_duplicates(keep='first')
# Out:
#       is_spam                                                sms
# 0           0  Go until jurong point, crazy.. Available only ...
# 1           0                      Ok lar... Joking wif u oni...
# 2           1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3           0  U dun say so early hor... U c already then say...
# 4           0  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567        1  This is the 2nd time we have tried 2 contact u...
# 5568        0            Will ï¿½_ b going to esplanade fr home?
# 5569        0  Pity, * was in mood for that. So...any other s...
# 5570        0  The guy did some bitching but I acted like i'd...
# 5571        0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %% [markdown]
# # EDA

# %%
df_new['is_spam'].value_counts()
# Out:
# 0    4825
# 1     747
# Name: is_spam, dtype: int64

# %%
plt.pie(df_new['is_spam'].value_counts(),labels=['ham','spam'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcc5dc1c340>,
# ...
#  [Text(-1.0038714981945518, 0.4497132587689916, 'ham'),
#   Text(1.0038714771419537, -0.4497133057636076, 'spam')])

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/teksinghayer/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df_new['num_characters']=df_new['sms'].apply(len)

# %%
df_new.head()
# Out:
#    is_spam                                                sms  num_characters
# 0        0  Go until jurong point, crazy.. Available only ...             111
# 1        0                      Ok lar... Joking wif u oni...              29
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3        0  U dun say so early hor... U c already then say...              49
# 4        0  Nah I don't think he goes to usf, he lives aro...              61

# %%
df_new['num_words']=df_new['sms'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
#number of sentences
df_new['num_sentences']=df_new['sms'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df_new.head()
# Out:
#    is_spam                                                sms  num_characters  \
# 0        0  Go until jurong point, crazy.. Available only ...             111
# 1        0                      Ok lar... Joking wif u oni...              29
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3        0  U dun say so early hor... U c already then say...              49
# 4        0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
sns.histplot(df_new[df_new['is_spam']==0]['num_characters'])
sns.histplot(df_new[df_new['is_spam']==1]['num_characters'])
# Out:
# <AxesSubplot: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,7))
sns.histplot(df_new[df_new['is_spam']==0]['num_words'])
sns.histplot(df_new[df_new['is_spam']==1]['num_words'],color='Green')
# Out:
# <AxesSubplot: xlabel='num_words', ylabel='Count'>

# %%
sns.heatmap(df_new.corr(),annot=True)
# Out:
# /var/folders/kb/f1k4_th17h992yvkrm2v50d40000gn/T/ipykernel_10310/1504224248.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_new.corr(),annot=True)
# <AxesSubplot: >

# %%
def clean_text(text):
    #change every word in lowercase
    text=text.lower()
    #seperate each word into lists
    text=nltk.word_tokenize(text)
    #removing special characters
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    text=y[:]
    y.clear()
    #removing punctuation and stopwords
    for i in text:
        if i not in stopwords.words('english')and i not in string.punctuation:
            y.append(i)
    #stemming
    text=y[:]
    y.clear()
    ps=PorterStemmer()
    for i in text:
        y.append(ps.stem(i))
    return " ".join(y)

# %%
clean_text('hi i am loving  english')
# Out:
# 'hi love english'

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/teksinghayer/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df_new['transformed_text']= df_new['sms'].apply(clean_text)

# %%
df_new
# Out:
#       is_spam                                                sms  \
# 0           0  Go until jurong point, crazy.. Available only ...
# 1           0                      Ok lar... Joking wif u oni...
# 2           1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3           0  U dun say so early hor... U c already then say...
# 4           0  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567        1  This is the 2nd time we have tried 2 contact u...
# 5568        0            Will ï¿½_ b going to esplanade fr home?
# 5569        0  Pity, * was in mood for that. So...any other s...
# 5570        0  The guy did some bitching but I acted like i'd...
# 5571        0                         Rofl. Its true to its name
#
#       num_characters  num_words  num_sentences  \
# 0                111         24              2
# 1                 29          8              2
# ...

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')
spam_wc=wc.generate(df_new[df_new['is_spam']==1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure()
plt.imshow(spam_wc)

# %%
spam_wc = wc.generate(df_new[df_new['is_spam']==0]['tranformed_text'].str.cat(sep=" "))

# %%
plt.figure()
plt.imshow(spam_wc)

# %% [markdown]
# # Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()

# %%
X=cv.fit_transform(df_new['transformed_text']).toarray()

# %%
y=df_new['is_spam'].values

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=2)

# %%
from sklearn.naive_bayes import BernoulliNB,MultinomialNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
model=BernoulliNB()

# %%
model.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
y_predict=model.predict(x_test)

# %%
print(accuracy_score(y_test,y_predict))
# Out:
# 0.9705671213208902

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[1196,    2],
#        [  39,  156]])
